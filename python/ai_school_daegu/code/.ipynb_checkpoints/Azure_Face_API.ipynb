# %% [markdown]
# ## Face API Sample

# %%
import requests
from io import BytesIO
from PIL import Image, ImageDraw, ImageFont

# %%
subscription_key = "af30cb4ec2a44010a054185e92b1a7bd"
face_api_url = "https://daegufaceapi.cognitiveservices.azure.com/face/v1.0/detect"

# %%
image_url = 'http://spnimage.edaily.co.kr/images/photo/files/NP/S/2021/04/PS21041300066.jpg'

# %%
img = Image.open(BytesIO(requests.get(image_url).content))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=670x479 at 0x1D744965430>

# %%
headers = {'Ocp-Apim-Subscription-Key': subscription_key}
params = {
    'returnFaceId':'true',
    'returnFaceLandmarks':'false',
    'returnFaceAttributes':'age,gender,emotion'
}
data = {'url':image_url}
response = requests.post(face_api_url, params = params, headers = headers, json = data)
faces = response.json()

# %%
faces
# Out:
# [{'faceId': '882fa692-1010-4dfe-90c1-ad68c69c858b',
#   'faceRectangle': {'top': 81, 'left': 106, 'width': 53, 'height': 53},
#   'faceAttributes': {'gender': 'female',
#    'age': 22.0,
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.998,
#     'neutral': 0.002,
#     'sadness': 0.0,
#     'surprise': 0.0}}},
#  {'faceId': 'cc33afd9-5333-4bb5-98d0-6915abb05a2a',
#   'faceRectangle': {'top': 82, 'left': 507, 'width': 52, 'height': 52},
#   'faceAttributes': {'gender': 'female',
#    'age': 22.0,
#    'emotion': {'anger': 0.0,
#     'contempt': 0.001,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.037,
#     'neutral': 0.961,
#     'sadness': 0.001,
#     'surprise': 0.0}}},
#  {'faceId': '8b69f24a-ab73-4aed-8908-ad16b978902b',
#   'faceRectangle': {'top': 72, 'left': 244, 'width': 52, 'height': 52},
#   'faceAttributes': {'gender': 'female',
#    'age': 24.0,
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 1.0,
#     'neutral': 0.0,
#     'sadness': 0.0,
#     'surprise': 0.0}}},
#  {'faceId': 'b20be4cb-35a3-45ab-b831-0f5c3a842fd8',
#   'faceRectangle': {'top': 82, 'left': 382, 'width': 51, 'height': 51},
#   'faceAttributes': {'gender': 'female',
#    'age': 20.0,
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 1.0,
#     'neutral': 0.0,
#     'sadness': 0.0,
#     'surprise': 0.0}}}]

# %% [markdown]
# ## 얼굴 이정표
# [얼굴이정표](https://docs.microsoft.com/ko-kr/azure/cognitive-services/face/concepts/face-detection)
#
# ![얼굴이정표](https://docs.microsoft.com/ko-kr/azure/cognitive-services/face/images/landmarks.1.jpg)

# %%
def CreateImage(faces):

    for face in faces:
        
        # 사각형 출력하기 위한 부분
        rect = face['faceRectangle']
        top = rect['top']
        left = rect['left']
        bottom = rect['height'] + top
        right = rect['width'] + left

        draw.rectangle(((left,top),(right,bottom)), outline='red')

        # 사진 위에 글씨를 쓰는 부분
        fontX = left
        fontY = top - 18
        
        face_info = face['faceAttributes']
        gender = face_info['gender']
        age = face_info['age']
        result = 'Gender: {0} Age: {1}'.format(gender, age)

        draw.text((fontX, fontY), result, fill = "red", spacing = 1)

# %%
draw = ImageDraw.Draw(img)

# %%
CreateImage(faces)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=670x479 at 0x1D744965430>
